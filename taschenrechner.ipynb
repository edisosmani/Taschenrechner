# %% [markdown]
# ## Beispiel 1

# %%
text = """
=====================================
==         Taschenrechner          ==
=====================================
"""
print(text)
num1 = float(input("Zahl1: "))
num2 = float(input("Zahl2: "))

summe = num1 + num2
print("Zahl1: ", num1)
print("Zahl2: ", num2)
print("Ergebnis:", summe)
# Out:
# =====================================
# ==         Taschenrechner          ==
# =====================================
#
# Zahl1:  2.0
# Zahl2:  3.0
# Ergebnis: 5.0

# %% [markdown]
# ## Beispiel 2

# %%
text = """
=====================================
==         Taschenrechner          ==
=====================================
"""
print(text)
num1 = float(input("Zahl1: "))
num2 = float(input("Zahl2: "))
op = str(input("Rechenzeichen: "))
print("Zahl1: ", num1)
print("Zahl2: ", num2)

if op == "+":
    sum = num1 + num2
    print("Die Summe: ", sum)
elif op == "-":
    diff = num1 - num2
    print("Die Differenz: ", diff)
elif op == "*":
    product = num1 * num2
    print("Die Multiplikation: ", product)
elif op == "/":
    quotient = num1 / num2
    print("Die Division: ", quotient)
else:
    print("Rechenzeichen nicht gefunden!")
# Out:
# =====================================
# ==         Taschenrechner          ==
# =====================================
#
# Zahl1:  5.0
# Zahl2:  4.0
# Die Multiplikation:  20.0

# %% [markdown]
# ## Beispiel 3

# %%
text = """
=====================================
==         Taschenrechner          ==
=====================================
"""
print(text)

while True:
    try:
        num1 = float(input("Zahl1: "))
        break
    except ValueError:
        print(f"Die Eingabe '{num1}' ist keine gültige Zahl, bitte erneut.")
print("Eingabe akzeptiert:", num1)

while True:
    try:
        num2 = float(input("Zahl2: "))
        break
    except ValueError:
        print(f"Die Eingabe '{num2}' ist keine gültige Zahl")
print("Eingabe akzeptiert:", num2)

op = str(input("Rechenzeichen: "))
print("Zahl1: ", num1)
print("Zahl2: ", num2)
print("Ihre Rechnung: ", num1, op, num2)

if op == "+":
    sum = num1 + num2
    print("Die Summe: ", sum)
elif op == "-":
    diff = num1 - num2
    print("Die Differenz: ", diff)
elif op == "*":
    product = num1 * num2
    print("Die Multiplikation: ", product)
elif op == "/":
    quotient = num1 / num2
    print("Die Division: ", quotient)
else:
    print("Rechenzeichen nicht gefunden!")
# Out:
# =====================================
# ==         Taschenrechner          ==
# =====================================
#
# Eingabe akzeptiert: 3.0
# Eingabe akzeptiert: 70.0
# Zahl1:  3.0
# Zahl2:  70.0
# Ihre Rechnung:  3.0 * 70.0
# Die Multiplikation:  210.0
