# %% [markdown]
# ## Beispiel 1

# %%
text = """
=====================================
==         Taschenrechner          ==
=====================================
"""
print(text)
zahl1 = float(input("Zahl1: "))
zahl2 = float(input("Zahl2: "))

summe = zahl1 + zahl2
print("Zahl1: ", zahl1)
print("Zahl2: ", zahl2)
print("Ergebnis:", summe)
# Out:
# ...
# ==         Taschenrechner          ==
# ...
#
# Zahl1:  2.0
# Zahl2:  3.0
# Ergebnis: 5.0

# %% [markdown]
# ## Beispiel 2
